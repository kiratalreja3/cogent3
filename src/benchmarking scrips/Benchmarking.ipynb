# %%
from cogent3.core.annotation import GffAnnotationDb

# %%
from cogent3.core.annotation import GffAnnotationDb
from cogent3.parse.gff import gff_parser

gff_path = '/Users/kiratalreja/Downloads/prok_NoLocusTags.gff'
db = GffAnnotationDb(gff_path)
db.find_records(bio_type='CDS')
# Out:
# [{'name': 'CDS0', 'type': 'CDS', 'spans': [(189, 255)]},
#  {'name': 'CDS1', 'type': 'CDS', 'spans': [(336, 2799)]},
#  {'name': 'CDS2', 'type': 'CDS', 'spans': [(2800, 3733)]},
#  {'name': 'CDS3', 'type': 'CDS', 'spans': [(3733, 5020)]},
#  {'name': 'CDS4', 'type': 'CDS', 'spans': [(6200, 6089), (6459, 6201)]},
#  {'name': 'CDS5', 'type': 'CDS', 'spans': [(7959, 6528)]}]

# %%
import cProfile
cProfile.run("db.find_records(bio_type='CDS')")
# Out:
#          87 function calls in 0.002 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.002    0.002 <string>:1(<module>)
#         7    0.000    0.000    0.000    0.000 __init__.py:299(loads)
#         1    0.000    0.000    0.001    0.001 annotation.py:561(db_query)
#         1    0.000    0.000    0.000    0.000 annotation.py:570(_make_sql_query)
#         1    0.000    0.000    0.002    0.002 annotation.py:590(find_records)
#         7    0.000    0.000    0.000    0.000 decoder.py:332(decode)
#         7    0.000    0.000    0.000    0.000 decoder.py:343(raw_decode)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         1    0.000    0.000    0.002    0.002 {built-in method builtins.exec}
#         7    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
# ...

# %%
from cogent3 import load_aligned_seqs

seqs = load_aligned_seqs("/Users/kiratalreja/repos/test_files/fasta:gff/GCF_000005845.2_ASM584v2_genomic.fna", moltype="dna")

# %%
seqs.annotate_from_gff('/Users/kiratalreja/repos/test_files/fasta:gff/GCF_000005845.2_ASM584v2_genomic.gff')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/kiratalreja/repos/Cogent3/src/Benchmarking.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/kiratalreja/repos/Cogent3/src/Benchmarking.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> seqs.annotate_from_gff('/Users/kiratalreja/repos/test_files/fasta:gff/GCF_000005845.2_ASM584v2_genomic.gff')
#
# AttributeError: 'ArrayAlignment' object has no attribute 'annotate_from_gff'

# %%
seqs.annotate_from_gff('/Users/kiratalreja/repos/test_files/fasta:gff/GCF_000005845.2_ASM584v2_genomic.gff')

# %%
import json
import os
import re

from pickle import dumps
from unittest import TestCase, main

from numpy import array
from numpy.testing import assert_allclose, assert_equal

from cogent3.core.annotation import Feature, SimpleVariable, Variable
from cogent3.core.moltype import (
    ASCII,
    BYTES,
    DNA,
    RNA,
    AlphabetError,
    get_moltype,
)
from cogent3.core.sequence import (
    ABSequence,
    ArrayCodonSequence,
    ArrayDnaCodonSequence,
    ArrayDnaSequence,
    ArrayNucleicAcidSequence,
    ArrayProteinSequence,
    ArrayRnaCodonSequence,
    ArrayRnaSequence,
    ArraySequence,
    DnaSequence,
    ProteinSequence,
    RnaSequence,
    Sequence,
)
from cogent3.util.misc import get_object_provenance

# %%
from cogent3.parse.fasta import FastaParser
import os
fasta_path = os.path.join("/Users/kiratalreja/Desktop/short.fsa")
gff3_path = os.path.join("/Users/kiratalreja/Downloads/prok_NoLocusTags.gff")
name, seq = next(FastaParser(fasta_path))

sequence = Sequence(seq)
sequence.annotate_from_gff(gff3_path)

# %%
sequence
# Out:
# Sequence(AGCTTTT... 13720)

# %%
from cogent3.parse.fasta import FastaParser
from cogent3 import load_unaligned_seqs
from cogent3.parse.gff import gff_parser

def fix_gff(gff):
    return [r for r in gff if r["Attributes"]['ID']]

fasta_path = "/Users/kiratalreja/Downloads/Homo_sapiens.GRCh38.dna.chromosome.1.fa"
gff3_path = "/Users/kiratalreja/Downloads/Homo_sapiens.GRCh38.108.chromosome.1.gff3"

gff= list(gff_parser(gff3_path))
gff = fix_gff(gff)

seqs = load_unaligned_seqs(fasta_path,moltype='dna')

seq = seqs.seqs[0]
seq.name = "1"

seq.annotate_from_gff(gff, pre_parsed=True)
seq.get_annotations_matching("gene")
# Out:
# [gene "gene:ENSG00000186092" at [65418:71585]/248956422,
#  gene "gene:ENSG00000284733" at [451678:450739]/248956422,
#  gene "gene:ENSG00000284662" at [686654:685715]/248956422,
#  gene "gene:ENSG00000187634" at [923922:944575]/248956422,
#  gene "gene:ENSG00000188976" at [959309:944202]/248956422,
#  gene "gene:ENSG00000187961" at [960583:965719]/248956422,
#  gene "gene:ENSG00000187583" at [966481:975865]/248956422,
#  gene "gene:ENSG00000187642" at [982117:975197]/248956422,
#  gene "gene:ENSG00000188290" at [1000172:998961]/248956422,
#  gene "gene:ENSG00000187608" at [1001137:1014540]/248956422,
#  gene "gene:ENSG00000188157" at [1020119:1056118]/248956422,
#  gene "gene:ENSG00000237330" at [1074306:1070966]/248956422,
#  gene "gene:ENSG00000131591" at [1116361:1081817]/248956422,
#  gene "gene:ENSG00000162571" at [1173879:1197936]/248956422,
#  gene "gene:ENSG00000186891" at [1206592:1203507]/248956422,
#  gene "gene:ENSG00000186827" at [1214153:1211325]/248956422,
# ...

# %%
import cProfile
cProfile.run("seq.get_annotations_matching('gene')")
# Out:
#          41721 function calls in 0.032 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.032    0.032 <string>:1(<module>)
#         1    0.023    0.023    0.032    0.032 annotation.py:178(get_annotations_matching)
#      5660    0.004    0.000    0.008    0.000 fnmatch.py:25(fnmatch)
#      5660    0.001    0.000    0.003    0.000 fnmatch.py:70(fnmatchcase)
#     11320    0.002    0.000    0.002    0.000 posixpath.py:52(normcase)
#         1    0.000    0.000    0.032    0.032 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#     11320    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#      2096    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
# ...

# %%
from cogent3.core.annotation import GffAnnotationDb
from cogent3.parse.gff import gff_parser

gff_path = '/Users/kiratalreja/Downloads/Homo_sapiens.GRCh38.108.chromosome.1.gff3'
db = GffAnnotationDb(gff_path)
db.find_records(bio_type='gene')
# Out:
# [{'name': 'gene:ENSG00000186092', 'type': 'gene', 'spans': [(65418, 71585)]},
#  {'name': 'gene:ENSG00000284733', 'type': 'gene', 'spans': [(451678, 450739)]},
#  {'name': 'gene:ENSG00000284662', 'type': 'gene', 'spans': [(686654, 685715)]},
#  {'name': 'gene:ENSG00000187634', 'type': 'gene', 'spans': [(923922, 944575)]},
#  {'name': 'gene:ENSG00000188976', 'type': 'gene', 'spans': [(959309, 944202)]},
#  {'name': 'gene:ENSG00000187961', 'type': 'gene', 'spans': [(960583, 965719)]},
#  {'name': 'gene:ENSG00000187583', 'type': 'gene', 'spans': [(966481, 975865)]},
#  {'name': 'gene:ENSG00000187642', 'type': 'gene', 'spans': [(982117, 975197)]},
#  {'name': 'gene:ENSG00000188290',
#   'type': 'gene',
#   'spans': [(1000172, 998961)]},
#  {'name': 'gene:ENSG00000187608',
#   'type': 'gene',
#   'spans': [(1001137, 1014540)]},
#  {'name': 'gene:ENSG00000188157',
#   'type': 'gene',
#   'spans': [(1020119, 1056118)]},
#  {'name': 'gene:ENSG00000237330',
#   'type': 'gene',
# ...

# %%
cProfile.run("db.find_records(bio_type='gene')")
# Out:
#          20976 function calls in 0.169 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.001    0.001    0.169    0.169 <string>:1(<module>)
#      2096    0.001    0.000    0.013    0.000 __init__.py:299(loads)
#         1    0.000    0.000    0.149    0.149 annotation.py:561(db_query)
#         1    0.000    0.000    0.000    0.000 annotation.py:570(_make_sql_query)
#         1    0.006    0.006    0.168    0.168 annotation.py:590(find_records)
#      2096    0.002    0.000    0.011    0.000 decoder.py:332(decode)
#      2096    0.007    0.000    0.007    0.000 decoder.py:343(raw_decode)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         1    0.000    0.000    0.169    0.169 {built-in method builtins.exec}
#      2096    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
# ...
