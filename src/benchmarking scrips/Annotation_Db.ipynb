# %%
from __future__ import annotations

import abc
import json
import sqlite3
from typing import Optional, TypeVar

from cogent3 import open_
from cogent3.parse.genbank import MinimalGenbankParser
from cogent3.parse.gff import gff_parser

T = Optional[str]
R = TypeVar(
    "R"
)  # define properly, a typed dict, we need to ensure appropriate keys in a dict for constructing cogent3.annotation.Feature instances


class AnnotationDbBase(abc.ABC):
    @abc.abstractmethod
    def find_records(
        self, *,
        seq_name: T = None,
        bio_type: T = None,
        identifier: T = None,
        start: int = None,
        end: int = None,
        strand: T = None,
    ) -> R:
        """returns matching records"""

    @abc.abstractmethod
    def distinct(
        self, *,
        seq_name: bool = False,
        bio_type: bool = False,
        identifier: bool = False,
    ) -> set[str]:
        """returns the number of distinct values matching records"""


def _ordered_values(values: dict) -> list:
    # doc strings for all methods and functions
    # c3dev instructions for docstrings --numpy docstring format
    # vscode extension

    keys = (
        "SeqID",
        "Source",
        "Type",
        "Start",
        "End",
        "Score",
        "Strand",
        "Phase",
        "Attributes",
    )
    return [values[k] for k in keys]


def _make_gff3_db():
    conn = sqlite3.connect(":memory:")
    conn.row_factory = sqlite3.Row

    c = conn.cursor()
    #add a primary key
    c.execute(
        """ CREATE TABLE GFF (
                SeqID text,
                Source text,
                Type text,
                Start integer,
                End integer, 
                Score text,
                Strand text,
                Phase text,
                Attributes text
            
            )"""
    )

    return c


class GffAnnotationDb(AnnotationDbBase):
    def __init__(self, path):
        self.db = _make_gff3_db()
        self._populate_from_file(path)

    def _populate_from_file(self, path):
        for record in gff_parser(path):
            data = _ordered_values(dict(record))
            data[-1] = json.dumps(data[-1])
            self.db.execute(
                "INSERT INTO GFF VALUES (?,?,?,?,?,?,?,?,?)",
                data,
            )

    def db_query(
        self, *, seq_name: T = None, bio_type: T = None, identifier: T = None
    ):  # what return type
        query, values = self._make_sql_query(
            seq_name=seq_name, bio_type=bio_type, identifier=identifier
        )
        self.db.execute(query, tuple(values))
        return self.db.fetchall()

    def _make_sql_query(
        self,
        *,
        seq_name: T = None,
        bio_type: T = None,
        identifier: T = None,
        start: int = None,
        end: int = None,
    ):
        # The user must provide one of the following arguments
        if not any([bio_type, identifier]):
            raise ValueError("no arguments provided")

        query = "SELECT * FROM GFF WHERE "
        clauses = []
        values = []

        if seq_name:
            clauses.append("SeqID == ?")
            values.append(seq_name)

        if bio_type:
            clauses.append("Type == ?")
            values.append(bio_type)

        if identifier:
            # identifier can be stored as "ID" or "Parent"
            clauses.append("Attributes like ?")
            values.append(f"%{identifier}%")

        if start is not None and end is not None:
            clauses.append("Start >= ? AND End < ?")
            values.extend((start, end))
        elif start is not None:
            clauses.append("Start >= ?")
            values.append(start)
        elif end is not None:
            clauses.append("End < ?")
            values.append(end)

        return query + " AND ".join(clauses), values

    def find_records(
        self, *, seq_name: T = None, bio_type: T = None, identifier: T = None
    ) -> list[R]:
        # this needs to be a typed dict
        rowdict = {}
        for row in self.db_query(
            seq_name=seq_name, bio_type=bio_type, identifier=identifier
        ):
            attr = json.loads(row["Attributes"])
            id_ = attr["ID"]

            if id_ not in rowdict:
                rowdict[id_] = {
                    "name": id_,
                    "type": row["Type"],
                    "spans": [(row["Start"], row["End"])],
                }
            else:
                rowdict[id_]["spans"].append((row["Start"], row["End"]))

        return list(rowdict.values())

    def distinct(
        self, *,
        seq_name: bool = False,
        bio_type: bool = False,
        identifier: bool = False,
    ) -> set:

        if not any ([seq_name,bio_type,identifier]):
            return set()

        components = []
        query_template = 'SELECT DISTINCT {} FROM gff'

        value_dict = dict()

        if seq_name:
            seq_name_set = set()
            query_template_seq = query_template.format("SeqID")
            self.db.execute('SELECT DISTINCT SeqID FROM gff')
            result = self.db.fetchall()
            for row in result:
                seq_name_set.add(row['SeqID'])
            value_dict['SeqID'] = seq_name_set

        if bio_type:
            type_set = set()
            query_template_type = query_template.format("Type")
            self.db.execute('SELECT DISTINCT Type FROM gff')
            result = self.db.fetchall()
            for row in result:
                type_set.add(row['Type'])
            value_dict['Type'] = type_set

        if identifier:
            identifier_set = set()
            query_template_identifier = query_template.format("Attributes")
            self.db.execute('SELECT DISTINCT Attributes FROM gff')
            result = self.db.fetchall()
            for row in result:
                identifier_set.add(json.loads(row['Attributes'])['ID'])
            value_dict['identifier'] = identifier_set

        
        return value_dict


def _fetch_from_features(feature):
    location = [(f.first() - 1, f.last()) for f in feature["location"]]
    start = location[0][0]
    end = location[-1][1]
    strand = feature["location"].strand()
    return [
        feature["type"],
        json.dumps(location),
        feature["locus_tag"],
        start,
        end,
        strand,
    ]


def _make_genbank_db():
    conn = sqlite3.connect(":memory:")
    conn.row_factory = sqlite3.Row

    c = conn.cursor()

    c.execute(
        """ CREATE TABLE GENBANK (
                LocusID text,
                Type text,
                Spans text,
                Locus_Tag text,
                Start integer,
                End integer,
                Strand text
            )"""
    )

    return c


class GenbankAnnotationDb(AnnotationDbBase):
    def __init__(self, path):
        self.db = _make_genbank_db()
        self._populate_from_file(path)

    def _populate_from_file(self, path):
        with open_(path) as infile:
            data = list(MinimalGenbankParser(infile.readlines()))

        record = data[0]
        locus_id = record["locus"]
        sql_template = "INSERT INTO GENBANK VALUES {}"
        sql = None
        for feature in record["features"][1:]:
            if "locus_tag" not in list(feature.keys()):
                continue

            data = _fetch_from_features(feature)
            data.insert(0, locus_id)

            if sql is None:
                data_placeholder = f"({','.join(('?',)*len(data))})"
                sql = sql_template.format(data_placeholder)

            self.db.execute(
                sql,
                data,
            )

    def db_query(
        self,
        *,
        seq_name: T = None,
        bio_type: T = None,
        identifier: T = None,
        start: int = None,
        end: int = None,
        strand: T = None,
    ):
        query, values = self._make_sql_query(
            bio_type=bio_type, identifier=identifier, start=start, end=end
        )
        self.db.execute(""" SELECT LocusID FROM GENBANK LIMIT 1""")
        values.insert(0, seq_name)
        self.db.execute(query, tuple(values))
        return self.db.fetchall()

    def _make_sql_query(
        self,
        *,
        bio_type: T = None,
        identifier: T = None,
        start: int = None,
        end: int = None,
        strand: T = None,
    ):
        # The user must provide one of the following arguments
        if not any([bio_type, identifier]):
            raise ValueError("no arguments provided")

        query = "SELECT * FROM GENBANK WHERE LocusID == ? AND "
        clauses = []
        values = []

        if bio_type:
            clauses.append("Type == ?")
            values.append(bio_type)

        if identifier:
            clauses.append("Locus_Tag like ?")
            values.append(f"%{identifier}%")

        if start is not None and end is not None:
            clauses.append("Start >= ? AND End < ?")
            values.extend((start, end))
        elif start is not None:
            clauses.append("Start >= ?")
            values.append(start)
        elif end is not None:
            clauses.append("End < ?")
            values.append(end)

        return query + " AND ".join(clauses), values

    def find_records(
        self,
        *,
        seq_name: T = None,
        bio_type: T = None,
        identifier: T = None,
        start: int = None,
        end: int = None,
        strand: T = None,
    ) -> R:
        rowdict = {}
        for row in self.db_query(
            seq_name=seq_name,
            bio_type=bio_type,
            identifier=identifier,
            start=start,
            end=end,
            strand=strand,
        ):
            id_ = json.loads(row["Locus_Tag"])[0]

            dict_value = id_ + row["Type"]

            rowdict[dict_value] = {
                "name": id_,
                "type": row["Type"],
                "spans": json.loads(row["Spans"]),
            }

        return list(rowdict.values())

# %%
gff3_path = "/Users/kiratalreja/Downloads/Homo_sapiens.GRCh38.108.chromosome.1.gff3"
db = GffAnnotationDb(gff3_path)

# %%
dict = db.distinct(seq_name='True',bio_type='True',identifier='True')

# %%
dict
# Out:
# {'SeqID': {'1'},
#  'Type': {'CDS',
#   'biological_region',
#   'chromosome',
#   'exon',
#   'five_prime_UTR',
#   'gene',
#   'lnc_RNA',
#   'mRNA',
#   'miRNA',
#   'ncRNA',
#   'ncRNA_gene',
#   'pseudogene',
#   'pseudogenic_transcript',
#   'rRNA',
#   'scRNA',
#   'snRNA',
#   'snoRNA',
#   'three_prime_UTR',
#   'transcript',
#   'unconfirmed_transcript'},
#  'identifier': {'',
#   'transcript:ENST00000441083',
#   'transcript:ENST00000442510',
#   'transcript:ENST00000481786',
#   'CDS:ENSP00000234827',
#   'gene:ENSG00000117598',
#   'transcript:ENST00000527567',
#   'CDS:ENSP00000481743',
#   'gene:ENSG00000237781',
#   'transcript:ENST00000454199',
#   'transcript:ENST00000478835',
#   'transcript:ENST00000695680',
#   'transcript:ENST00000679724',
#   'CDS:ENSP00000355973',
#   'transcript:ENST00000675359',
#   'transcript:ENST00000281881',
#   'transcript:ENST00000374253',
#   'gene:ENSG00000186094',
#   'transcript:ENST00000427173',
#   'transcript:ENST00000447592',
#   'transcript:ENST00000488868',
#   'CDS:ENSP00000497795',
#   'CDS:ENSP00000489188',
#   'gene:ENSG00000233645',
#   'transcript:ENST00000672099',
#   'gene:ENSG00000238934',
#   'gene:ENSG00000169717',
#   'transcript:ENST00000466180',
#   'transcript:ENST00000644540',
#   'transcript:ENST00000383965',
#   'transcript:ENST00000496197',
#   'transcript:ENST00000528078',
#   'CDS:ENSP00000358060',
#   'CDS:ENSP00000390686',
#   'gene:ENSG00000263513',
#   'gene:ENSG00000132702',
#   'transcript:ENST00000683517',
#   'transcript:ENST00000471286',
#   'gene:ENSG00000233691',
#   'transcript:ENST00000613697',
#   'gene:ENSG00000233983',
#   'CDS:ENSP00000294724',
#   'gene:ENSG00000116729',
#   'transcript:ENST00000479593',
#   'transcript:ENST00000477559',
#   'transcript:ENST00000481871',
#   'transcript:ENST00000706290',
#   'gene:ENSG00000163141',
#   'transcript:ENST00000690243',
#   'gene:ENSG00000270818',
#   'transcript:ENST00000429942',
#   'transcript:ENST00000681370',
#   'gene:ENSG00000230214',
#   'CDS:ENSP00000309574',
#   'transcript:ENST00000461667',
#   'transcript:ENST00000438469',
#   'transcript:ENST00000632866',
#   'gene:ENSG00000143224',
#   'transcript:ENST00000363089',
#   'gene:ENSG00000162692',
#   'CDS:ENSP00000497052',
#   'transcript:ENST00000635218',
#   'transcript:ENST00000368196',
#   'gene:ENSG00000233664',
#   'transcript:ENST00000517430',
#   'gene:ENSG00000284443',
#   'transcript:ENST00000452699',
#   'transcript:ENST00000509700',
#   'CDS:ENSP00000166244',
#   'transcript:ENST00000532826',
#   'CDS:ENSP00000363116',
#   'transcript:ENST00000336300',
#   'transcript:ENST00000463116',
#   'transcript:ENST00000384610',
#   'transcript:ENST00000365621',
#   'transcript:ENST00000655399',
#   'CDS:ENSP00000313829',
#   'transcript:ENST00000490339',
#   'gene:ENSG00000271187',
#   'CDS:ENSP00000421588',
#   'transcript:ENST00000314011',
#   'gene:ENSG00000206791',
#   'gene:ENSG00000185523',
#   'transcript:ENST00000424379',
#   'transcript:ENST00000469392',
#   'transcript:ENST00000630130',
#   'gene:ENSG00000227236',
#   'transcript:ENST00000466752',
#   'transcript:ENST00000348581',
#   'transcript:ENST00000639935',
#   'CDS:ENSP00000512148',
#   'gene:ENSG00000236266',
#   'transcript:ENST00000596404',
#   'transcript:ENST00000470585',
#   'transcript:ENST00000418865',
#   'transcript:ENST00000479483',
#   'gene:ENSG00000117528',
#   'transcript:ENST00000426826',
#   'transcript:ENST00000689130',
#   'CDS:ENSP00000327316',
#   'transcript:ENST00000677807',
#   'CDS:ENSP00000476316',
#   'transcript:ENST00000465575',
#   'CDS:ENSP00000496473',
#   'CDS:ENSP00000476285',
#   'transcript:ENST00000450269',
#   'CDS:ENSP00000406531',
#   'transcript:ENST00000475911',
#   'transcript:ENST00000647794',
#   'CDS:ENSP00000358363',
#   'transcript:ENST00000650825',
#   'CDS:ENSP00000360991',
#   'transcript:ENST00000446905',
#   'transcript:ENST00000693043',
#   'transcript:ENST00000494942',
#   'transcript:ENST00000469495',
#   'transcript:ENST00000486918',
#   'CDS:ENSP00000357018',
#   'transcript:ENST00000689608',
#   'transcript:ENST00000478926',
#   'transcript:ENST00000465705',
#   'CDS:ENSP00000343924',
#   'gene:ENSG00000235492',
#   'transcript:ENST00000427213',
#   'gene:ENSG00000284702',
#   'gene:ENSG00000224359',
#   'transcript:ENST00000477554',
#   'CDS:ENSP00000359049',
#   'transcript:ENST00000368390',
#   'gene:ENSG00000227094',
#   'CDS:ENSP00000424342',
#   'transcript:ENST00000458715',
#   'transcript:ENST00000696026',
#   'gene:ENSG00000229687',
#   'gene:ENSG00000225196',
#   'CDS:ENSP00000255409',
#   'transcript:ENST00000676391',
#   'transcript:ENST00000649616',
#   'transcript:ENST00000509389',
#   'transcript:ENST00000637788',
#   'CDS:ENSP00000394373',
#   'transcript:ENST00000524442',
#   'transcript:ENST00000433562',
#   'transcript:ENST00000491055',
#   'CDS:ENSP00000362663',
#   'CDS:ENSP00000403207',
#   'transcript:ENST00000529796',
#   'CDS:ENSP00000494444',
#   'transcript:ENST00000271835',
#   'gene:ENSG00000157191',
#   'CDS:ENSP00000389866',
#   'transcript:ENST00000371905',
#   'CDS:ENSP00000482685',
#   'CDS:ENSP00000433143',
#   'transcript:ENST00000368729',
#   'CDS:ENSP00000509119',
#   'transcript:ENST00000452197',
#   'transcript:ENST00000663419',
#   'CDS:ENSP00000502092',
#   'transcript:ENST00000294623',
#   'CDS:ENSP00000355945',
#   'transcript:ENST00000430316',
#   'transcript:ENST00000700423',
#   'CDS:ENSP00000363060',
#   'transcript:ENST00000662236',
#   'CDS:ENSP00000502151',
#   'gene:ENSG00000284696',
#   'CDS:ENSP00000341621',
#   'transcript:ENST00000619797',
#   'CDS:ENSP00000432328',
#   'transcript:ENST00000371538',
#   'CDS:ENSP00000463055',
#   'transcript:ENST00000367079',
#   'gene:ENSG00000117009',
#   'transcript:ENST00000641463',
#   'transcript:ENST00000460879',
#   'CDS:ENSP00000398077',
#   'transcript:ENST00000476508',
#   'transcript:ENST00000371568',
#   'CDS:ENSP00000510137',
#   'transcript:ENST00000531191',
#   'CDS:ENSP00000457066',
#   'transcript:ENST00000678712',
#   'transcript:ENST00000543215',
#   'CDS:ENSP00000357679',
#   'transcript:ENST00000367999',
#   'CDS:ENSP00000507430',
#   'transcript:ENST00000429682',
#   'transcript:ENST00000422560',
#   'transcript:ENST00000476467',
#   'transcript:ENST00000577853',
#   'transcript:ENST00000493155',
#   'transcript:ENST00000430120',
#   'transcript:ENST00000691513',
#   'CDS:ENSP00000503400',
#   'transcript:ENST00000467830',
#   'transcript:ENST00000417209',
#   'transcript:ENST00000463614',
#   'transcript:ENST00000660747',
#   'transcript:ENST00000370938',
#   'gene:ENSG00000282111',
#   'transcript:ENST00000646821',
#   'transcript:ENST00000463015',
#   'CDS:ENSP00000356291',
#   'CDS:ENSP00000501681',
#   'CDS:ENSP00000502867',
#   'CDS:ENSP00000513364',
#   'transcript:ENST00000695822',
#   'transcript:ENST00000418985',
#   'transcript:ENST00000431691',
#   'transcript:ENST00000519906',
#   'transcript:ENST00000366983',
#   'transcript:ENST00000487174',
#   'CDS:ENSP00000493366',
#   'transcript:ENST00000669112',
#   'CDS:ENSP00000390113',
#   'gene:ENSG00000268154',
#   'transcript:ENST00000366610',
#   'transcript:ENST00000459463',
#   'transcript:ENST00000423723',
#   'transcript:ENST00000475659',
#   'transcript:ENST00000622533',
#   'transcript:ENST00000620248',
#   'gene:ENSG00000187862',
#   'CDS:ENSP00000477486',
#   'transcript:ENST00000493549',
#   'CDS:ENSP00000414888',
#   'CDS:ENSP00000499302',
#   'gene:ENSG00000143748',
#   'gene:ENSG00000231868',
#   'transcript:ENST00000679215',
#   'transcript:ENST00000368777',
#   'transcript:ENST00000675607',
#   'transcript:ENST00000458139',
#   'transcript:ENST00000392179',
#   'transcript:ENST00000443422',
#   'transcript:ENST00000460199',
#   'transcript:ENST00000372006',
#   'transcript:ENST00000517251',
#   'gene:ENSG00000197587',
#   'transcript:ENST00000367123',
#   'CDS:ENSP00000408952',
#   'transcript:ENST00000371919',
#   'gene:ENSG00000241860',
#   'gene:ENSG00000291129',
#   'gene:ENSG00000224645',
#   'CDS:ENSP00000400506',
#   'transcript:ENST00000329006',
#   'transcript:ENST00000648494',
#   'gene:ENSG00000126088',
#   'CDS:ENSP00000504170',
#   'transcript:ENST00000690240',
#   'CDS:ENSP00000407168',
#   'transcript:ENST00000691989',
#   'CDS:ENSP00000367476',
#   'transcript:ENST00000467071',
#   'transcript:ENST00000534289',
#   'gene:ENSG00000174332',
#   'gene:ENSG00000223062',
#   'transcript:ENST00000313667',
#   'gene:ENSG00000135821',
#   'gene:ENSG00000232995',
#   'transcript:ENST00000494444',
#   'CDS:ENSP00000359090',
#   'transcript:ENST00000699468',
#   'CDS:ENSP00000480439',
#   'transcript:ENST00000608580',
#   'CDS:ENSP00000359628',
#   'transcript:ENST00000694917',
#   'transcript:ENST00000676058',
#   'transcript:ENST00000497660',
#   'transcript:ENST00000639171',
#   'CDS:ENSP00000307307',
#   'CDS:ENSP00000356385',
#   'transcript:ENST00000685891',
#   'transcript:ENST00000703600',
#   'transcript:ENST00000467066',
#   'transcript:ENST00000701228',
#   'gene:ENSG00000287738',
#   'CDS:ENSP00000510597',
#   'transcript:ENST00000368236',
#   'CDS:ENSP00000513356',
#   'transcript:ENST00000676096',
#   'transcript:ENST00000478684',
#   'transcript:ENST00000460563',
#   'transcript:ENST00000654630',
#   'transcript:ENST00000625854',
#   'transcript:ENST00000641402',
#   'transcript:ENST00000490770',
#   'transcript:ENST00000494948',
#   'transcript:ENST00000342055',
#   'transcript:ENST00000457096',
#   'CDS:ENSP00000355840',
#   'transcript:ENST00000470041',
#   'transcript:ENST00000669314',
#   'gene:ENSG00000143149',
#   'CDS:ENSP00000397255',
#   'transcript:ENST00000389793',
#   'transcript:ENST00000517277',
#   'transcript:ENST00000407071',
#   'transcript:ENST00000251547',
#   'transcript:ENST00000639946',
#   'transcript:ENST00000488603',
#   'transcript:ENST00000472612',
#   'transcript:ENST00000659987',
#   'transcript:ENST00000368669',
#   'gene:ENSG00000215912',
#   'CDS:ENSP00000358919',
#   'gene:ENSG00000154511',
#   'transcript:ENST00000607193',
#   'transcript:ENST00000663818',
#   'gene:ENSG00000233271',
#   'gene:ENSG00000160050',
#   'transcript:ENST00000703693',
#   'transcript:ENST00000695771',
#   'CDS:ENSP00000366729',
#   'transcript:ENST00000455397',
#   'transcript:ENST00000608166',
#   'CDS:ENSP00000505130',
#   'CDS:ENSP00000497297',
#   'transcript:ENST00000470300',
#   'CDS:ENSP00000438141',
#   'transcript:ENST00000491626',
#   'transcript:ENST00000448301',
#   'gene:ENSG00000197532',
#   'transcript:ENST00000375116',
#   'transcript:ENST00000368186',
#   'CDS:ENSP00000425674',
#   'transcript:ENST00000368330',
#   'transcript:ENST00000614534',
#   'transcript:ENST00000368827',
#   'transcript:ENST00000474413',
#   'gene:ENSG00000160818',
#   'transcript:ENST00000471889',
#   'transcript:ENST00000656075',
#   'gene:ENSG00000169598',
#   'CDS:ENSP00000360642',
#   'gene:ENSG00000143387',
#   'CDS:ENSP00000347428',
#   'transcript:ENST00000697005',
#   'CDS:ENSP00000494857',
#   'CDS:ENSP00000436986',
#   'transcript:ENST00000585156',
#   'transcript:ENST00000456170',
#   'CDS:ENSP00000271452',
#   'CDS:ENSP00000476713',
#   'CDS:ENSP00000359531',
#   'transcript:ENST00000648058',
#   'gene:ENSG00000275291',
#   'transcript:ENST00000686286',
#   'transcript:ENST00000629624',
#   'transcript:ENST00000325945',
#   'CDS:ENSP00000479495',
#   'transcript:ENST00000450820',
#   'transcript:ENST00000641267',
#   'transcript:ENST00000487117',
#   'transcript:ENST00000651970',
#   'gene:ENSG00000283676',
#   'transcript:ENST00000431193',
#   'transcript:ENST00000681429',
#   'gene:ENSG00000221571',
#   'gene:ENSG00000235988',
#   'gene:ENSG00000117154',
#   'transcript:ENST00000462646',
#   'gene:ENSG00000287532',
#   'transcript:ENST00000461727',
#   'CDS:ENSP00000491903',
#   'transcript:ENST00000525113',
#   'transcript:ENST00000531355',
#   'transcript:ENST00000582693',
#   'transcript:ENST00000648583',
#   'transcript:ENST00000641212',
#   'transcript:ENST00000685957',
#   'transcript:ENST00000685822',
#   'CDS:ENSP00000436288',
#   'transcript:ENST00000641772',
#   'transcript:ENST00000427500',
#   'transcript:ENST00000685022',
#   'CDS:ENSP00000329210',
#   'transcript:ENST00000480045',
#   'transcript:ENST00000251296',
#   'transcript:ENST00000580971',
#   'transcript:ENST00000634589',
#   'gene:ENSG00000134247',
#   'transcript:ENST00000355014',
#   'CDS:ENSP00000490194',
#   'transcript:ENST00000686047',
#   'gene:ENSG00000159346',
#   'gene:ENSG00000186827',
#   'transcript:ENST00000677063',
#   'gene:ENSG00000225217',
#   'CDS:ENSP00000424228',
#   'gene:ENSG00000215909',
#   'transcript:ENST00000705662',
#   'gene:ENSG00000277918',
#   'transcript:ENST00000638467',
#   'transcript:ENST00000524472',
#   'CDS:ENSP00000415417',
#   'transcript:ENST00000634255',
#   'gene:ENSG00000196805',
#   'transcript:ENST00000608332',
#   'gene:ENSG00000223944',
#   'CDS:ENSP00000356060',
#   'transcript:ENST00000480952',
#   'CDS:ENSP00000360274',
#   'transcript:ENST00000477447',
#   'CDS:ENSP00000357398',
#   'CDS:ENSP00000361617',
#   'CDS:ENSP00000489689',
#   'CDS:ENSP00000362521',
#   'transcript:ENST00000449305',
#   'transcript:ENST00000493977',
#   'transcript:ENST00000651455',
#   'transcript:ENST00000654998',
#   'transcript:ENST00000605276',
#   'gene:ENSG00000285873',
#   'CDS:ENSP00000356301',
#   'transcript:ENST00000631679',
#   'gene:ENSG00000232751',
#   'transcript:ENST00000487074',
#   'transcript:ENST00000490065',
#   'transcript:ENST00000368720',
#   'transcript:ENST00000474632',
#   'CDS:ENSP00000415531',
#   'transcript:ENST00000528449',
#   'CDS:ENSP00000357424',
#   'CDS:ENSP00000361630',
#   'CDS:ENSP00000506428',
#   'transcript:ENST00000440200',
#   'transcript:ENST00000413074',
#   'transcript:ENST00000440729',
#   'transcript:ENST00000441760',
#   'transcript:ENST00000476904',
#   'transcript:ENST00000516057',
#   'transcript:ENST00000372827',
#   'transcript:ENST00000370143',
#   'CDS:ENSP00000354490',
#   'transcript:ENST00000611593',
#   'CDS:ENSP00000476589',
#   'gene:ENSG00000143842',
#   'gene:ENSG00000236327',
#   'transcript:ENST00000474874',
#   'CDS:ENSP00000354573',
#   'transcript:ENST00000441033',
#   'transcript:ENST00000472741',
#   'transcript:ENST00000372651',
#   'transcript:ENST00000379116',
#   'transcript:ENST00000659190',
#   'transcript:ENST00000702441',
#   'transcript:ENST00000460612',
#   'transcript:ENST00000434367',
#   'transcript:ENST00000294661',
#   'gene:ENSG00000235363',
#   'transcript:ENST00000681554',
#   'gene:ENSG00000227962',
#   'gene:ENSG00000134202',
#   'transcript:ENST00000471953',
#   'transcript:ENST00000367946',
#   'CDS:ENSP00000495928',
#   'transcript:ENST00000383932',
#   'CDS:ENSP00000494990',
#   'transcript:ENST00000364921',
#   'CDS:ENSP00000355632',
#   'transcript:ENST00000334232',
#   'transcript:ENST00000366934',
#   'transcript:ENST00000445071',
#   'transcript:ENST00000459640',
#   'transcript:ENST00000440116',
#   'transcript:ENST00000615360',
#   'CDS:ENSP00000366620',
#   'transcript:ENST00000367400',
#   'transcript:ENST00000411503',
#   'CDS:ENSP00000492495',
#   'transcript:ENST00000503672',
#   'transcript:ENST00000654944',
#   'transcript:ENST00000486238',
#   'transcript:ENST00000367057',
#   'gene:ENSG00000271143',
#   'transcript:ENST00000691165',
#   'CDS:ENSP00000478087',
#   'transcript:ENST00000363457',
#   'gene:ENSG00000233750',
#   'transcript:ENST00000685249',
#   'transcript:ENST00000480265',
#   'transcript:ENST00000495109',
#   'transcript:ENST00000612017',
#   'CDS:ENSP00000343928',
#   'CDS:ENSP00000433020',
#   'transcript:ENST00000578133',
#   'CDS:ENSP00000359121',
#   'transcript:ENST00000367635',
#   'CDS:ENSP00000463605',
#   'CDS:ENSP00000493236',
#   'transcript:ENST00000688741',
#   'CDS:ENSP00000433637',
#   'transcript:ENST00000367537',
#   'transcript:ENST00000651465',
#   'transcript:ENST00000487028',
#   'transcript:ENST00000383957',
#   'gene:ENSG00000226520',
#   'transcript:ENST00000429293',
#   'transcript:ENST00000611931',
#   'CDS:ENSP00000358045',
#   'transcript:ENST00000630588',
#   'transcript:ENST00000375406',
#   'transcript:ENST00000467064',
#   'gene:ENSG00000258634',
#   'CDS:ENSP00000498635',
#   'CDS:ENSP00000422349',
#   'transcript:ENST00000460687',
#   'transcript:ENST00000492095',
#   'CDS:ENSP00000271688',
#   'transcript:ENST00000636334',
#   'CDS:ENSP00000504569',
#   'transcript:ENST00000472233',
#   'CDS:ENSP00000399962',
#   'gene:ENSG00000215833',
#   'transcript:ENST00000607240',
#   'transcript:ENST00000431969',
#   'transcript:ENST00000467774',
#   'CDS:ENSP00000512180',
#   'CDS:ENSP00000453331',
#   'transcript:ENST00000373014',
#   'transcript:ENST00000434700',
#   'transcript:ENST00000525202',
#   'CDS:ENSP00000434276',
#   'transcript:ENST00000603614',
#   'transcript:ENST00000371065',
#   'CDS:ENSP00000494179',
#   'transcript:ENST00000368680',
#   'gene:ENSG00000291158',
#   'CDS:ENSP00000496054',
#   'transcript:ENST00000603887',
#   'CDS:ENSP00000358543',
#   'transcript:ENST00000441422',
#   'transcript:ENST00000677653',
#   'transcript:ENST00000656542',
#   'transcript:ENST00000701576',
#   'CDS:ENSP00000366800',
#   'transcript:ENST00000527941',
#   'CDS:ENSP00000474024',
#   'transcript:ENST00000486072',
#   'CDS:ENSP00000503539',
#   'transcript:ENST00000384591',
#   'transcript:ENST00000544913',
#   'CDS:ENSP00000348786',
#   'transcript:ENST00000657394',
#   'transcript:ENST00000495447',
#   'transcript:ENST00000462387',
#   'CDS:ENSP00000308339',
#   'transcript:ENST00000494378',
#   'transcript:ENST00000537531',
#   'transcript:ENST00000697222',
#   'transcript:ENST00000699259',
#   'gene:ENSG00000236528',
#   'CDS:ENSP00000402531',
#   'transcript:ENST00000663424',
#   'gene:ENSG00000291226',
#   'transcript:ENST00000370509',
#   'transcript:ENST00000260505',
#   'CDS:ENSP00000514717',
#   'transcript:ENST00000687613',
#   'gene:ENSG00000075945',
#   'CDS:ENSP00000398037',
#   'transcript:ENST00000516016',
#   'CDS:ENSP00000392765',
#   'CDS:ENSP00000503533',
#   'transcript:ENST00000430643',
#   'transcript:ENST00000464203',
#   'CDS:ENSP00000294401',
#   'CDS:ENSP00000413017',
#   'transcript:ENST00000359209',
#   'gene:ENSG00000160803',
#   'CDS:ENSP00000496832',
#   'gene:ENSG00000201492',
#   'CDS:ENSP00000495665',
#   'CDS:ENSP00000358844',
#   'transcript:ENST00000637430',
#   'transcript:ENST00000691006',
#   'CDS:ENSP00000427620',
#   'transcript:ENST00000463471',
#   'transcript:ENST00000491797',
#   'transcript:ENST00000569674',
#   'transcript:ENST00000368003',
#   'transcript:ENST00000479940',
#   'transcript:ENST00000639788',
#   'CDS:ENSP00000432057',
#   'transcript:ENST00000691303',
#   'transcript:ENST00000370486',
#   'transcript:ENST00000497615',
#   'transcript:ENST00000621573',
#   'transcript:ENST00000491586',
#   'transcript:ENST00000424712',
#   'transcript:ENST00000479322',
#   'transcript:ENST00000603760',
#   'CDS:ENSP00000431179',
#   'transcript:ENST00000641256',
#   'transcript:ENST00000605576',
#   'CDS:ENSP00000355562',
#   'transcript:ENST00000483408',
#   'transcript:ENST00000441524',
#   'CDS:ENSP00000355503',
#   'transcript:ENST00000462329',
#   'CDS:ENSP00000426627',
#   'transcript:ENST00000295367',
#   'gene:ENSG00000223787',
#   'gene:ENSG00000201114',
#   'transcript:ENST00000606857',
#   'gene:ENSG00000232341',
#   'gene:ENSG00000289697',
#   'transcript:ENST00000360115',
#   'transcript:ENST00000478728',
#   'gene:ENSG00000143653',
#   'transcript:ENST00000453860',
#   'CDS:ENSP00000270747',
#   'transcript:ENST00000664663',
#   'CDS:ENSP00000494583',
#   'transcript:ENST00000634495',
#   'transcript:ENST00000463664',
#   'CDS:ENSP00000395254',
#   'CDS:ENSP00000497385',
#   'transcript:ENST00000684286',
#   'transcript:ENST00000431514',
#   'gene:ENSG00000235358',
#   'CDS:ENSP00000355785',
#   'gene:ENSG00000230287',
#   'transcript:ENST00000432472',
#   'transcript:ENST00000681929',
#   'transcript:ENST00000368354',
#   'CDS:ENSP00000363963',
#   'gene:ENSG00000186118',
#   'gene:ENSG00000265491',
#   'transcript:ENST00000687604',
#   'gene:ENSG00000213244',
#   'gene:ENSG00000231605',
#   'gene:ENSG00000233399',
#   'gene:ENSG00000278267',
#   'transcript:ENST00000640951',
#   'gene:ENSG00000237188',
#   'transcript:ENST00000516598',
#   'gene:ENSG00000269621',
#   'CDS:ENSP00000239462',
#   'transcript:ENST00000444116',
#   'CDS:ENSP00000492308',
#   'CDS:ENSP00000361275',
#   'transcript:ENST00000473821',
#   'CDS:ENSP00000494042',
#   'transcript:ENST00000342280',
#   'transcript:ENST00000443438',
#   'transcript:ENST00000662327',
#   'CDS:ENSP00000434888',
#   'CDS:ENSP00000437206',
#   'CDS:ENSP00000358437',
#   'CDS:ENSP00000397537',
#   'transcript:ENST00000495259',
#   'transcript:ENST00000368235',
#   'gene:ENSG00000222784',
#   'gene:ENSG00000157077',
#   'transcript:ENST00000368242',
#   'CDS:ENSP00000513365',
#   'transcript:ENST00000369401',
#   'transcript:ENST00000348159',
#   'gene:ENSG00000162402',
#   'transcript:ENST00000663993',
#   'transcript:ENST00000482991',
#   'gene:ENSG00000235811',
#   'transcript:ENST00000653755',
#   'CDS:ENSP00000360968',
#   'transcript:ENST00000658231',
#   'transcript:ENST00000488789',
#   'transcript:ENST00000652048',
#   'CDS:ENSP00000479881',
#   'gene:ENSG00000213560',
#   'gene:ENSG00000223869',
#   'transcript:ENST00000619924',
#   'transcript:ENST00000637265',
#   'CDS:ENSP00000513031',
#   'transcript:ENST00000476273',
#   'transcript:ENST00000636564',
#   'transcript:ENST00000431541',
#   'transcript:ENST00000651781',
#   'transcript:ENST00000498158',
#   'transcript:ENST00000374208',
#   'transcript:ENST00000373019',
#   'transcript:ENST00000677505',
#   'transcript:ENST00000531337',
#   'transcript:ENST00000454305',
#   'CDS:ENSP00000347948',
#   'CDS:ENSP00000468392',
#   'transcript:ENST00000675829',
#   'transcript:ENST00000449169',
#   'gene:ENSG00000180098',
#   'CDS:ENSP00000502569',
#   'CDS:ENSP00000295694',
#   'CDS:ENSP00000356981',
#   'transcript:ENST00000479947',
#   'transcript:ENST00000361641',
#   'CDS:ENSP00000438136',
#   'gene:ENSG00000243062',
#   'CDS:ENSP00000499615',
#   'CDS:ENSP00000404290',
#   'transcript:ENST00000429499',
#   'transcript:ENST00000319637',
#   'CDS:ENSP00000507259',
#   'transcript:ENST00000618792',
#   'CDS:ENSP00000514422',
#   'transcript:ENST00000448345',
#   'transcript:ENST00000630199',
#   'transcript:ENST00000527035',
#   'CDS:ENSP00000506091',
#   'CDS:ENSP00000507764',
#   'transcript:ENST00000370207',
#   'transcript:ENST00000474352',
#   'transcript:ENST00000485680',
#   'transcript:ENST00000432574',
#   'CDS:ENSP00000426915',
#   'transcript:ENST00000640774',
#   'transcript:ENST00000644134',
#   'CDS:ENSP00000362852',
#   'CDS:ENSP00000361947',
#   'gene:ENSG00000207181',
#   'transcript:ENST00000368161',
#   'gene:ENSG00000283259',
#   'CDS:ENSP00000263733',
#   'transcript:ENST00000284617',
#   'CDS:ENSP00000359150',
#   'transcript:ENST00000445705',
#   'CDS:ENSP00000358313',
#   'gene:ENSG00000118873',
#   'transcript:ENST00000368623',
#   'transcript:ENST00000682931',
#   'transcript:ENST00000616125',
#   'transcript:ENST00000492152',
#   'CDS:ENSP00000440896',
#   'transcript:ENST00000368309',
#   'transcript:ENST00000678883',
#   'CDS:ENSP00000505455',
#   'gene:ENSG00000227527',
#   'transcript:ENST00000491112',
#   'transcript:ENST00000595188',
#   'CDS:ENSP00000411128',
#   'transcript:ENST00000460369',
#   'CDS:ENSP00000362566',
#   'transcript:ENST00000527263',
#   'gene:ENSG00000221879',
#   'transcript:ENST00000688863',
#   'transcript:ENST00000454068',
#   'CDS:ENSP00000356912',
#   'transcript:ENST00000373443',
#   'CDS:ENSP00000356888',
#   'gene:ENSG00000274642',
#   'transcript:ENST00000478564',
#   'transcript:ENST00000548815',
#   'CDS:ENSP00000506606',
#   'CDS:ENSP00000346921',
#   'CDS:ENSP00000485468',
#   'CDS:ENSP00000358035',
#   'transcript:ENST00000549094',
#   'transcript:ENST00000373710',
#   'transcript:ENST00000685497',
#   'transcript:ENST00000686048',
#   'transcript:ENST00000458657',
#   'transcript:ENST00000492343',
#   'CDS:ENSP00000376030',
#   'gene:ENSG00000162896',
#   'gene:ENSG00000162814',
#   'CDS:ENSP00000366418',
#   'transcript:ENST00000362371',
#   'CDS:ENSP00000493556',
#   'transcript:ENST00000465021',
#   'gene:ENSG00000163202',
#   'transcript:ENST00000376014',
#   'transcript:ENST00000615252',
#   'transcript:ENST00000294338',
#   'transcript:ENST00000366699',
#   'transcript:ENST00000681971',
#   'transcript:ENST00000447781',
#   'transcript:ENST00000271357',
#   'transcript:ENST00000513148',
#   'transcript:ENST00000455967',
#   'CDS:ENSP00000397759',
#   'transcript:ENST00000393300',
#   'gene:ENSG00000270585',
#   'CDS:ENSP00000346330',
#   'transcript:ENST00000442117',
#   'CDS:ENSP00000432392',
#   'transcript:ENST00000498166',
#   'transcript:ENST00000270722',
#   'transcript:ENST00000371626',
#   'gene:ENSG00000272583',
#   'transcript:ENST00000660568',
#   'transcript:ENST00000609678',
#   'CDS:ENSP00000358568',
#   'CDS:ENSP00000271843',
#   'CDS:ENSP00000409965',
#   'transcript:ENST00000609117',
#   'CDS:ENSP00000506242',
#   'transcript:ENST00000368533',
#   'gene:ENSG00000237700',
#   'transcript:ENST00000420125',
#   'transcript:ENST00000453569',
#   'gene:ENSG00000196189',
#   'CDS:ENSP00000431700',
#   'CDS:ENSP00000499771',
#   'CDS:ENSP00000357413',
#   'transcript:ENST00000482572',
#   'gene:ENSG00000010072',
#   'transcript:ENST00000608635',
#   'transcript:ENST00000679509',
#   'CDS:ENSP00000357442',
#   'transcript:ENST00000641006',
#   'gene:ENSG00000270850',
#   'CDS:ENSP00000362930',
#   'transcript:ENST00000686238',
#   'transcript:ENST00000599419',
#   'CDS:ENSP00000319664',
#   'CDS:ENSP00000424345',
#   'CDS:ENSP00000432452',
#   'CDS:ENSP00000426103',
#   'transcript:ENST00000440817',
#   'transcript:ENST00000461807',
#   'CDS:ENSP00000502346',
#   'transcript:ENST00000496578',
#   'CDS:ENSP00000476624',
#   'transcript:ENST00000368189',
#   'transcript:ENST00000532040',
#   'CDS:ENSP00000403560',
#   'CDS:ENSP00000514801',
#   'gene:ENSG00000235432',
#   'CDS:ENSP00000513171',
#   'gene:ENSG00000252760',
#   'CDS:ENSP00000507176',
#   'gene:ENSG00000117791',
#   'CDS:ENSP00000501803',
#   'transcript:ENST00000682383',
#   'transcript:ENST00000609653',
#   'CDS:ENSP00000505558',
#   'transcript:ENST00000633953',
#   'transcript:ENST00000526113',
#   'transcript:ENST00000527691',
#   'transcript:ENST00000518899',
#   'transcript:ENST00000475773',
#   'transcript:ENST00000392064',
#   'transcript:ENST00000664213',
#   'transcript:ENST00000619772',
#   'transcript:ENST00000696945',
#   'transcript:ENST00000689189',
#   'CDS:ENSP00000343943',
#   'gene:ENSG00000142606',
#   'transcript:ENST00000437963',
#   'transcript:ENST00000437146',
#   'transcript:ENST00000414775',
#   'transcript:ENST00000478442',
#   'transcript:ENST00000449524',
#   'transcript:ENST00000436811',
#   'transcript:ENST00000635247',
#   'transcript:ENST00000646921',
#   'transcript:ENST00000474292',
#   'gene:ENSG00000207190',
#   'transcript:ENST00000671979',
#   'transcript:ENST00000488537',
#   'CDS:ENSP00000513610',
#   'CDS:ENSP00000388991',
#   'transcript:ENST00000367093',
#   'gene:ENSG00000287472',
#   'transcript:ENST00000369903',
#   'CDS:ENSP00000473256',
#   'CDS:ENSP00000465308',
#   'transcript:ENST00000462324',
#   'CDS:ENSP00000356303',
#   'transcript:ENST00000617913',
#   'transcript:ENST00000470396',
#   'transcript:ENST00000674150',
#   'CDS:ENSP00000505961',
#   'transcript:ENST00000618315',
#   'transcript:ENST00000688352',
#   'CDS:ENSP00000364139',
#   'transcript:ENST00000373243',
#   'CDS:ENSP00000501330',
#   'transcript:ENST00000369872',
#   'CDS:ENSP00000498250',
#   'transcript:ENST00000496872',
#   'transcript:ENST00000371072',
#   'transcript:ENST00000703022',
#   'gene:ENSG00000234937',
#   'transcript:ENST00000607338',
#   'gene:ENSG00000233540',
#   'transcript:ENST00000681280',
#   'CDS:ENSP00000368624',
#   'CDS:ENSP00000431985',
#   'gene:ENSG00000143771',
#   'CDS:ENSP00000401622',
#   'CDS:ENSP00000509451',
#   'CDS:ENSP00000431288',
#   'transcript:ENST00000618779',
#   'transcript:ENST00000695747',
#   'gene:ENSG00000159023',
#   'transcript:ENST00000402322',
#   'transcript:ENST00000681519',
#   'transcript:ENST00000488251',
#   'CDS:ENSP00000323795',
#   'transcript:ENST00000497314',
#   'gene:ENSG00000177800',
#   'transcript:ENST00000493171',
#   'CDS:ENSP00000416857',
#   'CDS:ENSP00000398822',
#   'transcript:ENST00000498544',
#   'transcript:ENST00000610197',
#   'gene:ENSG00000237605',
#   'gene:ENSG00000069812',
#   'CDS:ENSP00000512203',
#   'transcript:ENST00000642416',
#   'transcript:ENST00000479151',
#   'CDS:ENSP00000294794',
#   'transcript:ENST00000604728',
#   'transcript:ENST00000647691',
#   'gene:ENSG00000225514',
#   'transcript:ENST00000465596',
#   'transcript:ENST00000655747',
#   'transcript:ENST00000460057',
#   'transcript:ENST00000448134',
#   'CDS:ENSP00000431836',
#   'transcript:ENST00000701866',
#   'CDS:ENSP00000502115',
#   'transcript:ENST00000635220',
#   'CDS:ENSP00000355298',
#   'CDS:ENSP00000356828',
#   'transcript:ENST00000530528',
#   'gene:ENSG00000228058',
#   'transcript:ENST00000505841',
#   'transcript:ENST00000491857',
#   'CDS:ENSP00000494824',
#   'transcript:ENST00000354955',
#   'transcript:ENST00000645691',
#   'transcript:ENST00000429744',
#   'gene:ENSG00000232917',
#   'transcript:ENST00000686658',
#   'transcript:ENST00000497228',
#   'transcript:ENST00000393614',
#   'transcript:ENST00000437879',
#   'transcript:ENST00000480202',
#   'transcript:ENST00000494839',
#   'transcript:ENST00000447284',
#   'transcript:ENST00000480581',
#   'transcript:ENST00000381357',
#   'transcript:ENST00000371870',
#   'transcript:ENST00000652871',
#   'transcript:ENST00000696109',
#   'transcript:ENST00000438243',
#   'transcript:ENST00000392802',
#   'CDS:ENSP00000435851',
#   'transcript:ENST00000512340',
#   'transcript:ENST00000495334',
#   'transcript:ENST00000368273',
#   'transcript:ENST00000364551',
#   'gene:ENSG00000233079',
#   'CDS:ENSP00000509341',
#   'transcript:ENST00000480586',
#   'transcript:ENST00000426444',
#   'transcript:ENST00000503842',
#   'transcript:ENST00000703095',
#   'CDS:ENSP00000383909',
#   'CDS:ENSP00000363400',
#   'transcript:ENST00000493940',
#   'CDS:ENSP00000361392',
#   'gene:ENSG00000225713',
#   'transcript:ENST00000455405',
#   'gene:ENSG00000235089',
#   'CDS:ENSP00000431366',
#   'CDS:ENSP00000508876',
#   'transcript:ENST00000366960',
#   'transcript:ENST00000476088',
#   'CDS:ENSP00000417826',
#   'CDS:ENSP00000348333',
#   'transcript:ENST00000397332',
#   'transcript:ENST00000460293',
#   'gene:ENSG00000137941',
#   'transcript:ENST00000524999',
#   'transcript:ENST00000696209',
#   'CDS:ENSP00000483170',
#   'transcript:ENST00000438623',
#   'transcript:ENST00000662017',
#   'transcript:ENST00000495791',
#   'CDS:ENSP00000359142',
#   'transcript:ENST00000420347',
#   'transcript:ENST00000609244',
#   'CDS:ENSP00000435176',
#   'CDS:ENSP00000361440',
#   'gene:ENSG00000291242',
#   'CDS:ENSP00000475192',
#   'CDS:ENSP00000496756',
#   'CDS:ENSP00000443495',
#   'transcript:ENST00000614015',
#   'transcript:ENST00000367563',
#   'transcript:ENST00000628573',
#   'CDS:ENSP00000431654',
#   'transcript:ENST00000577855',
#   'gene:ENSG00000272562',
#   'transcript:ENST00000483143',
#   'transcript:ENST00000656201',
#   ...}}
